# %%
# !git clone https://github.com/SIT-COMP-1210/Module2-Breakout-{MeronMammo}.git
# Out:
# Cloning into 'Module2-Breakout-{MeronMammo}'...
# remote: Repository not found.
# fatal: repository 'https://github.com/SIT-COMP-1210/Module2-Breakout-{MeronMammo}.git/' not found

# %% [markdown]
# **Data Types Exercise**

# %% [markdown]
# What is the type of 2?

# %%
print(type(2))
# Out:
# <class 'int'>

# %% [markdown]
# What is the type of 2.0?

# %%
print(type(2.0))
# Out:
# <class 'float'>

# %% [markdown]
# What is the resulting type of adding 2 and 2?

# %%
print(type(2+2))
# Out:
# <class 'int'>

# %% [markdown]
# What is the type of ‘Programming’ ?

# %%
print(type('Programming'))
# Out:
# <class 'str'>

# %% [markdown]
# What is the resulting output when you add ‘Computer’ and ‘Programming’?

# %%
print('Computer'+'Programming')
# Out:
# ComputerProgramming

# %% [markdown]
# What is the resulting output when you add ‘Programming’ and ‘Computer’?

# %%
print('Programming'+'Computer')
# Out:
# ProgrammingComputer

# %% [markdown]
# Is there a difference between single quotes (‘ ‘) and double quotes
# (“ “)?

# %%
print("There is essentially no difference between them becasue both help to make strings and multi-line strings. However, one of them can be used inside the other")
# Out:
# There is essentially no difference between them becasue both help to make strings and multi-line strings. However, one of them can be used inside the other

# %% [markdown]
# What happens when you add 10 and  ‘10’? Why?

# %%
print("An error message appears because we cannot evaluate operations between different data types.")
# Out:
# An error message appears because we cannot evaluate operations between different data types.

# %% [markdown]
# What is the result of ‘Ethiopia’ * 3 ?

# %%
print('Ethiopia'*3)
# Out:
# EthiopiaEthiopiaEthiopia

# %% [markdown]
# What is the result of 10.0 * 7?

# %%
print(10.0*7)
# Out:
# 70.0

# %% [markdown]
# Are ‘Programming’ and ‘programming’ equivalent?

# %%
print('Python is case-sensative. Hence, due to capitalization of p, they are not equivalent')
print(bool("Programming"=="programming"))
# Out:
# Python is case-sensative. Hence, due to capitalization of p, they are not equivalent
# False

# %% [markdown]
# Are 150 and ‘150’ equivalent?

# %%
print(150=='150')
print("These are different data types so aren't equivalent")
# Out:
# False
# These are different data types so aren't equivalent

# %% [markdown]
# Fix the following code so it prints ‘I am 18 years old’:
#         print(‘I am’ + 18 + ‘years old’)

# %%
print("I am "+str(18)+" years old")
print("I am 18 years old")
# Out:
# I am 18 years old
# I am 18 years old

# %% [markdown]
# Translate these statements into Pythonic expressions and  evaluate the Boolean:
#
#
# *   The sum of 5 and 5 is less than 10
# *   The value of 10//2 is equal to 2 + 3
#
#
# *   The sum of 1, 5, 2, 4 is greater than 15
# *   157 is even
#
# *   The sum of 5 squared and 12 squared is equal to 169

# %%
print(bool(5+5 <10))

print(bool(10//2 == 2+3))

print(bool(1+5+2+4 > 15))

print(bool(157%2==0))

print(bool(5**2 + 12**2 ==169))
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# Write code to produce
#
# *  ‘Selam4’
# *  ‘SelamSelamSelamSelam’
#
# You may only write ‘Selam’ once and 4 once for each part.

# %%
print("Selam"+str(4))
print("Selam"*4)
# Out:
# Selam4
# SelamSelamSelamSelam
