# %% [markdown]
# <a href="https://colab.research.google.com/github/MeronMammo/module2-breakout-meron-source/blob/main/module2_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module2-Breakout-{MeronMammo}.git
# Out:
# Cloning into 'Module2-Breakout-{MeronMammo}'...
# remote: Repository not found.
# fatal: repository 'https://github.com/SIT-COMP-1210/Module2-Breakout-{MeronMammo}.git/' not found

# %% [markdown]
# **Data Types and Arithmetic Operators Exercise**

# %% [markdown]
# 1. What is the type of 2?

# %%
print("The type of 2 is an integer because it is a number with no decimals")
print(type(2))
# Out:
# The type of 2 is an integer
# <class 'int'>

# %% [markdown]
# 2. What is the type of 2.0?

# %%
print("2.0 is a float because it is a number with a decimal")
print(type(2.0))
# Out:
# 2.0 is a float because it is a number with a decimal
# <class 'float'>

# %% [markdown]
# 3. What is the resulting type of adding 2 and 2?

# %%
print("The type of the value resulting from adding 2 and 2 is 4 which is an integer")
print(type(2+2))
# Out:
# The type of the value resultig from adding 2 and 2 is 4 which is an integer
# <class 'int'>

# %% [markdown]
# 4. What is the type of ‘Programming’ ?

# %%
print('Programming is a string because it is a sequence of characters surrounded by quotation marks')
print(type('Programming'))
# Out:
# Programming is a string because it is a sequence of characters surrounded by quotation marks
# <class 'str'>

# %% [markdown]
# 5. What is the resulting output when you add ‘Programming’ and ‘Computer’?

# %%
print('The result is a string ProgrammingComputer that is a concatenation of the two strigs')
print('Programming'+'Computer')
# Out:
# The result is a string ProgrammingComputer that is a concatenation of the two strigs
# ProgrammingComputer

# %% [markdown]
# 6. What is the result of ‘Ethiopia’ * 3 ?

# %%
print("The result is the string containing the word Ethiopia 3 times")
print('Ethiopia'*3)
# Out:
# The result is the string containing the word Ethiopia 3 times
# EthiopiaEthiopiaEthiopia

# %% [markdown]
# 7. What is the result of 10.0 * 7?

# %%
print("The result is a float, 70.0 because one of the operands, 10.0, is a number with a decimal")
print(10.0*7)
# Out:
# The result is a float, 70.0 because one of the operands, 10.0, is a number with a decimal
# 70.0

# %% [markdown]
# 8. What is stored in result?

# %%
result = str(int(2.8))
print("result is a string because first, 2.8 is changed to integer then the integer into srtring")
print(type(result))
# Out:
# result is a string because first, 2.8 is changed to integer then the integer into srtring
# <class 'str'>

# %% [markdown]
# 9. What is the final value and type of x?

# %%
x = int(float(-5))
print(x)
print(type(x))
# Out:
# -5
# <class 'int'>

# %% [markdown]
# 10. What is stored in expr? What is the order of operations?

# %%
expr = "a" + "b" * 2 + "c"
print(expr)
print("Based on PEMDAS,multiplication is first then addition from let to right")
# Out:
# abbc
# Based on PEMDAS,multiplication is first then addition from let to right

# %% [markdown]
# 11. What is the final value of value?

# %%
value = 100 / 5 // 4 * 3 % 5
print(value)
# Out:
# 0.0

# %% [markdown]
# 12. hat is the value of b? Why does this happen?

# %%
b = bool(0)
print(b)
print("The argument 0 returns false similar to other empty values like '' and None")
# Out:
# False
# The argument 0 returns false similar to other empty values like '' and None

# %% [markdown]
# 13. Why are the results numerically the same but types different?

# %%
a = 4 * 3
b = 4 * 3.0
print("Because  contains a float so the evaluated results becomes a float")
# Out:
# Because  contains a float so the evaluated results becomes a float

# %% [markdown]
# 14. Does calling int() on an int or float() on a float change the value? Why or why not?

# %%
x = int(5)
y = float(5.0)
print("No, because it is already in that data type")
# Out:
# No, because it is already in that data type

# %% [markdown]
# 15. What is the value and type of x?

# %%
x = 2 ** 3
print(x)
print(type(x))
# Out:
# 8
# <class 'int'>

# %% [markdown]
# 16. What is the value of y?

# %%
y = 4 * 2 ** 2
print(y)
# Out:
# 16

# %% [markdown]
# 17. What is the value of a?

# %%
a = 5 - 1 + 4 * 2
print(a)
# Out:
# 12

# %% [markdown]
# 18. What is the value of b?

# %%
b = (5 - 1 + 4) * 2
print(b)
# Out:
# 16

# %% [markdown]
# 19. What are the values of b1 and b2? Are they the same? If not, why are they different?

# %%
b1 = bool("")
b2 = bool("False")
print("No, because b1 returns the boolean False while b2 returns the boolean True becasue a string is the argument")
# Out:
# No, because b1 returns the boolean False while b2 returns the boolean True becasue a string is the argument

# %% [markdown]
# 20. Is (2 + 3) * 4 an expression or a function?

# %%
print("It is an expression because it contains operands and operations, together called an expression")
# Out:
# It is an expression because it contains operands and operations, together called an expression

# %% [markdown]
# 21. What is the final value of result?

# %%
result = str(int(5.9) + 2 ** 2) * 2
print(result)
# Out:
# 99
